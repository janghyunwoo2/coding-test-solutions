# %%
'''
아이디어 1

'''
def solution(N):
    
    return 0

# %%
# 테스트 케이스
input = None
output = None

# %%
# 테스트 함수
def test(solution):

    # 비교하기
    if output == solution(input):
        print(f'예상 값={output}, 출력 값={solution(input)}')
        return "통과"
    else:
        print(f'예상 값={output}, 출력 값={solution(input)}')
        return "틀림"

# %%
test(solution)
# Out:
# 예상 값=[1], 출력 값=[1]
# '통과'
